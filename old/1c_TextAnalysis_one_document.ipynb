# %% [markdown]
# # Text Analysis in Python 1: Working with Strings & Files
#
# <h1 style="text-align:center;font-size:300%;">The State of the Union is ... long?</h1>
#   <!--<img src="https://miro.medium.com/max/720/1*pp7HX01jBv2wbVRW9Ml_mA.png" style="width:%80;">-->
#   <img src = "https://cdn.theatlantic.com/thumbor/7G7_MhUOYg6M8JGSmbQCVoaJ-kY=/126x0:1794x938/1536x864/media/img/2015/01/16/opener_words/original.jpg">
#
# ## INTRODUCTION TO TEXT ANALYSIS IN PYTHON
# **How can we use computational techniques to analyze texts and then visualize patterns buried within them?**
#
# **What can we learn about texts by applying text analysis in Python? How do we get started?**
#
# <p>In this session, participants will:</p>
#
# + Learn how to write basic scripts in Python using Jupyter Notebooks
# + import and pre-process documents
# + analyze each document using word frequencies, collocations, ngram frequencies, etc.

# %% [markdown]
# ## This Tutorial
#
# In this tutorial and notebook, you will practice working with a dataset or corpus of a well-known series of texts: the yearly State of the Union addresses given by Presidents of the United States since 1790.
#
# For a great resource to learn and gain more practice doing text analysis with Python see the online book: Melanie Walsh, [*Introduction to Cultural Analytics and Python*](https://melaniewalsh.github.io/Intro-Cultural-Analytics/welcome.html), Version 1 (2021), https://doi.org/10.5281/zenodo.4411250.
#
# <img src="https://melaniewalsh.github.io/Intro-Cultural-Analytics/_static/favicon.ico" style="width:30%">
#
# <!--All sections below labeled with a **MW** comes from this book. Please consider supporting that project if you find it useful.-->

# %% [markdown]
# ## Part I. Getting Started
#
# <h3 style="color:gold">Downloading and Saving Dataset(s)</h3>
#
# ??

# %% [markdown]
# ## This Tutorial
#
# In this tutorial and notebook, you will practice working with a dataset or corpus of a well-known series of texts: the yearly State of the Union addresses given by Presidents of the United States since 1790.

# %% [markdown]
# ## Part I: Importing Python Packages or Libraries
#
# 1. Before beginning, we need to import some packages. Often, we need to install and import customized Python packages (sometimes called "modules") in addition to the core functions (like **print()**, **len()**, **sum()**, and others).

# %%
import os, pathlib, glob #these packages allow us to navigate through the files on our own computers
from pathlib import Path #the pathlib package helps us work with file paths
#for more on using pathlib see: https://builtin.com/software-engineering-perspectives/python-pathlib
import pandas as pd #for creating and working with dataframes
import nltk,re #we can import multiple packages on one line using commas to separate new package names
from nltk import RegexpTokenizer 
from nltk.corpus import stopwords
from nltk import ngrams, pos_tag, word_tokenize, sent_tokenize
nltk.download('punkt')
#import matplotlib as plt   #matplotlib and seaborn are used here to create graphs, charts, and other visualizations
import matplotlib.pyplot as plt #needed for xticks
import seaborn as sns

#code below modifies how plots will be shown in this notebook
plt.rcParams['figure.figsize'] = [12, 8]  #changes default figure size to make larger plots
# %config InteractiveShellApp.matplotlib = 'inline'
# %config InlineBackend.figure_formats = ['svg']

#Press CTRL+Enter to run this codeblock!
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\F0040RP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# 1b. If the above prints out the error message: "ModuleNotFoundError: No module named 'nltk'". Uncomment out the code below (by removing the #) and run it. Then run the above cell of code (with all the import commands) again.

# %%
#!pip install nltk

# %% [markdown]
# <h3 style="color:green;"> Code Together:</h3>
#
# <p style="color:green">2. We will also need to use the "collections" package as well. Let's import that in the code cell below:</p>

# %%
#note: when importing packages, Python will only print something out if there is an error. 
import collections
#Press CTRL+Enter to run this codeblock!

# %% [markdown]
# # Part II: Navigating through the files in a directory (whether on your computer or on a remote server)
#
# <!--1. To work with the State of the Union addresses you downloaded (hereafter: SOTU), we will need to navigate to the folder you placed them in. First, check the "current working directory" that Python is working with:-->
# 3. To work with our State of the Union address text corpus, we will need to navigate to the folder we placed them in.

# %%
print(Path.cwd())  #prints out the current working directory (where Python will look for files unless we specify otherwise)
# Out:
# C:\Users\F0040RP\Documents\DartLib_RDS\external_Workshops\StAnselm\workshopMaterials_StAnselmDH\data-day1-texts

# %% [markdown]
# 4. Your current working directory, printed out in the previous step, is the location where this notebook is saved.

# %%
list(Path.iterdir(Path.cwd()))

#Do you see the "state of the union dataset" folder in the list below?
# Out:
# [WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/.ipynb_checkpoints'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/1a_Python_Basics.ipynb'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/1c_TextAnalysis_one_document.ipynb'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/1d_TextAnalysis_corpus.ipynb'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/1e_xml_practice.ipynb'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/completed_1c_TextAnalysis_one_document.ipynb'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/completed_1d_TextAnalysis_corpus.ipynb'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/lts_xml'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/metadata_Occom_docs.csv'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/occom'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/occom-select'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/Occom_xml_review.ipynb'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/practice.ipynb'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/state-of-the-union-dataset'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/test.ipynb'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/TextAnalysis.ipynb'),
#  WindowsPath('C:/Users/F0040RP/Documents/DartLib_RDS/external_Workshops/StAnselm/workshopMaterials_StAnselmDH/data-day1-texts/Untitled.ipynb')]

# %% [markdown]
# 5. Next, we will look inside the "state-of-the-union-dataset" folder containing our corpus of State of the Union speeches (henceforth: SOTU). We can learn something about this dataset simply by examining the titles of the individual files.

# %%
sotudir = Path(Path.cwd(), "state-of-the-union-dataset","txt")
print(set([item.suffix for item in list(Path.iterdir(sotudir))]))  #get unique suffixes or file extensions in sotudir 
[item.name for item in list(Path.iterdir(sotudir))] #to get filename only
# Out:
# {'.txt'}
# ['1790_Washington.txt',
#  '1791_Washington.txt',
#  '1792_Washington.txt',
#  '1793_Washington.txt',
#  '1794_Washington.txt',
#  '1795_Washington.txt',
#  '1796_Washington.txt',
#  '1797_Adams.txt',
#  '1798_Adams.txt',
#  '1799_Adams.txt',
#  '1800_Adams.txt',
#  '1801_Jefferson.txt',
#  '1802_Jefferson.txt',
#  '1803_Jefferson.txt',
#  '1804_Jefferson.txt',
#  '1805_Jefferson.txt',
#  '1806_Jefferson.txt',
#  '1807_Jefferson.txt',
#  '1808_Jefferson.txt',
#  '1809_Madison.txt',
#  '1810_Madison.txt',
#  '1811_Madison.txt',
#  '1812_Madison.txt',
#  '1813_Madison.txt',
#  '1814_Madison.txt',
#  '1815_Madison.txt',
#  '1816_Madison.txt',
#  '1817_Monroe.txt',
#  '1818_Monroe.txt',
#  '1819_Monroe.txt',
#  '1820_Monroe.txt',
#  '1821_Monroe.txt',
#  '1822_Monroe.txt',
#  '1823_Monroe.txt',
#  '1824_Monroe.txt',
#  '1825_Adams.txt',
#  '1826_Adams.txt',
#  '1827_Adams.txt',
#  '1828_Adams.txt',
#  '1829_Jackson.txt',
#  '1830_Jackson.txt',
#  '1831_Jackson.txt',
#  '1832_Jackson.txt',
#  '1833_Jackson.txt',
#  '1834_Jackson.txt',
#  '1835_Jackson.txt',
#  '1836_Jackson.txt',
#  '1837_Buren.txt',
#  '1838_Buren.txt',
#  '1839_Buren.txt',
#  '1840_Buren.txt',
#  '1841_Tyler.txt',
#  '1842_Tyler.txt',
#  '1843_Tyler.txt',
#  '1844_Tyler.txt',
#  '1845_Polk.txt',
#  '1846_Polk.txt',
#  '1847_Polk.txt',
#  '1848_Polk.txt',
#  '1849_Taylor.txt',
#  '1850_Fillmore.txt',
#  '1851_Fillmore.txt',
#  '1852_Fillmore.txt',
#  '1853_Pierce.txt',
#  '1854_Pierce.txt',
#  '1855_Pierce.txt',
#  '1856_Pierce.txt',
#  '1857_Buchanan.txt',
#  '1858_Buchanan.txt',
#  '1859_Buchanan.txt',
#  '1860_Buchanan.txt',
#  '1861_Lincoln.txt',
#  '1862_Lincoln.txt',
#  '1863_Lincoln.txt',
#  '1864_Lincoln.txt',
#  '1865_Johnson.txt',
#  '1866_Johnson.txt',
#  '1867_Johnson.txt',
#  '1868_Johnson.txt',
#  '1869_Grant.txt',
#  '1870_Grant.txt',
#  '1871_Grant.txt',
#  '1872_Grant.txt',
#  '1873_Grant.txt',
#  '1874_Grant.txt',
#  '1875_Grant.txt',
#  '1876_Grant.txt',
#  '1877_Hayes.txt',
#  '1878_Hayes.txt',
#  '1879_Hayes.txt',
#  '1880_Hayes.txt',
#  '1881_Arthur.txt',
#  '1882_Arthur.txt',
#  '1883_Arthur.txt',
#  '1884_Arthur.txt',
#  '1885_Cleveland.txt',
#  '1886_Cleveland.txt',
#  '1887_Cleveland.txt',
#  '1888_Cleveland.txt',
#  '1889_Harrison.txt',
#  '1890_Harrison.txt',
#  '1891_Harrison.txt',
#  '1892_Harrison.txt',
#  '1893_Cleveland.txt',
#  '1894_Cleveland.txt',
#  '1895_Cleveland.txt',
#  '1896_Cleveland.txt',
#  '1897_McKinley.txt',
#  '1898_McKinley.txt',
#  '1899_McKinley.txt',
#  '1900_McKinley.txt',
#  '1901_Roosevelt.txt',
#  '1902_Roosevelt.txt',
#  '1903_Roosevelt.txt',
#  '1904_Roosevelt.txt',
#  '1905_Roosevelt.txt',
#  '1906_Roosevelt.txt',
#  '1907_Roosevelt.txt',
#  '1908_Roosevelt.txt',
#  '1909_Taft.txt',
#  '1910_Taft.txt',
#  '1911_Taft.txt',
#  '1912_Taft.txt',
#  '1913_Wilson.txt',
#  '1914_Wilson.txt',
#  '1915_Wilson.txt',
#  '1916_Wilson.txt',
#  '1917_Wilson.txt',
#  '1918_Wilson.txt',
#  '1919_Wilson.txt',
#  '1920_Wilson.txt',
#  '1921_Harding.txt',
#  '1922_Harding.txt',
#  '1923_Coolidge.txt',
#  '1924_Coolidge.txt',
#  '1925_Coolidge.txt',
#  '1926_Coolidge.txt',
#  '1927_Coolidge.txt',
#  '1928_Coolidge.txt',
#  '1929_Hoover.txt',
#  '1930_Hoover.txt',
#  '1931_Hoover.txt',
#  '1932_Hoover.txt',
#  '1934_Roosevelt.txt',
#  '1935_Roosevelt.txt',
#  '1936_Roosevelt.txt',
#  '1937_Roosevelt.txt',
#  '1938_Roosevelt.txt',
#  '1939_Roosevelt.txt',
#  '1940_Roosevelt.txt',
#  '1941_Roosevelt.txt',
#  '1942_Roosevelt.txt',
#  '1943_Roosevelt.txt',
#  '1944_Roosevelt.txt',
#  '1945_Roosevelt.txt',
#  '1946_Truman.txt',
#  '1947_Truman.txt',
#  '1948_Truman.txt',
#  '1949_Truman.txt',
#  '1950_Truman.txt',
#  '1951_Truman.txt',
#  '1952_Truman.txt',
#  '1953_Truman.txt',
#  '1954_Eisenhower.txt',
#  '1955_Eisenhower.txt',
#  '1956_Eisenhower.txt',
#  '1957_Eisenhower.txt',
#  '1958_Eisenhower.txt',
#  '1959_Eisenhower.txt',
#  '1960_Eisenhower.txt',
#  '1961_Eisenhower.txt',
#  '1962_Kennedy.txt',
#  '1963_Kennedy.txt',
#  '1964_Johnson.txt',
#  '1965_Johnson.txt',
#  '1966_Johnson.txt',
#  '1967_Johnson.txt',
#  '1968_Johnson.txt',
#  '1969_Johnson.txt',
#  '1970_Nixon.txt',
#  '1971_Nixon.txt',
#  '1972_Nixon.txt',
#  '1973_Nixon.txt',
#  '1974_Nixon.txt',
#  '1975_Ford.txt',
#  '1976_Ford.txt',
#  '1977_Ford.txt',
#  '1978_Carter.txt',
#  '1979_Carter.txt',
#  '1980_Carter.txt',
#  '1981_Carter.txt',
#  '1982_Reagan.txt',
#  '1983_Reagan.txt',
#  '1984_Reagan.txt',
#  '1985_Reagan.txt',
#  '1986_Reagan.txt',
#  '1987_Reagan.txt',
#  '1988_Reagan.txt',
#  '1989_Bush.txt',
#  '1990_Bush.txt',
#  '1991_Bush.txt',
#  '1992_Bush.txt',
#  '1993_Clinton.txt',
#  '1994_Clinton.txt',
#  '1995_Clinton.txt',
#  '1996_Clinton.txt',
#  '1997_Clinton.txt',
#  '1998_Clinton.txt',
#  '1999_Clinton.txt',
#  '2000_Clinton.txt',
#  '2001_Bush.txt',
#  '2002_Bush.txt',
#  '2003_Bush.txt',
#  '2004_Bush.txt',
#  '2005_Bush.txt',
#  '2006_Bush.txt',
#  '2007_Bush.txt',
#  '2008_Bush.txt',
#  '2009_Obama.txt',
#  '2010_Obama.txt',
#  '2011_Obama.txt',
#  '2012_Obama.txt',
#  '2013_Obama.txt',
#  '2014_Obama.txt',
#  '2015_Obama.txt',
#  '2016_Obama.txt',
#  '2017_Trump.txt',
#  '2018_Trump.txt',
#  '2019_Trump.txt',
#  '2020_Trump.txt',
#  '2021_Biden.txt',
#  '2022_Biden.txt',
#  '2023_Biden.txt']

# %% [markdown]
# ## Part III: Reading Files and Examining Their Contents

# %% [markdown]
# 6. Open one SOTU text.

# %%
with open(Path(sotudir,"2002_Bush.txt"),encoding='utf-8') as f:
    sotu1 = f.read()

## ** calling utf-8 encoding may not be necessary
## but is good practice if you ever work with foreign languages (besides special characters can appear in English too, as in 
## loan words like naïve and résumé )


##[DISCUSS WHY IT IS GOOD PRACTICE TO CLOSE FILES IMMEDIATELY AFTER YOU ARE DONE WITH THEM]

# %%
## we can view the whole text simply by typing the file name
sotu1[-500:]  #Jupyter, however, requires the print() command to print out any information not found in the last line of code in a codeblock
# Out:
# ".\n\nOur enemies send other people's children on missions of suicide and murder. They\nembrace tyranny and death as a cause and a creed. We stand for a different\nchoice, made long ago on the day of our founding. We affirm it again today. We\nchoose freedom and the dignity of every life.\n\nSteadfast in our purpose, we now press on. We have known freedom's price. We\nhave shown freedom's power. And in this great conflict, my fellow Americans, we\nwill see freedom's victory.\n\nThank you all. May God bless."

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p style="color:green"><b>6b. Code Together</b>: Open a second SOTU address (of your own choosing) and save it into the variable "sotu2".</p>
# </div>

# %%
with open(Path(sotudir,"1864_Lincoln.txt"),encoding='utf-8') as f:
    sotu2 = f.read()

# %% [markdown]
# 7. What do the following blocks of code do? Run them and then share your answer.

# %%
print(len(sotu2))
# Out:
# 36164

# %%
sotu1[0:200]
# Out:
# 'Thank you very much. Mr. Speaker, Vice President Cheney, Members of Congress,\ndistinguished guests, fellow citizens: As we gather tonight, our Nation is at\nwar; our economy is in recession; and the ci'

# %%
sotu1[:20]
# Out:
# 'Thank you very much.'

# %%
sotu1[1000:1200]
# Out:
# 'his evening we welcomed the distinguished interim\nleader of a liberated Afghanistan, Chairman Hamid Karzai.\n\nThe last time we met in this Chamber, the mothers and daughters of Afghanistan\nwere captive'

# %%
sotu1[-60:]
# Out:
# "e\nwill see freedom's victory.\n\nThank you all. May God bless."

# %% [markdown]
# <h3 style="color:blue;">Exercises for Part III</h3>
#
# <p style="color:blue;">8. Add a coding cell below and print out the first and last 200 characters in your selected <b>sotu2</b> address. Can you identify any major themes from the opening and closing words of this address? If not, expand the number of characters you are examining.</p>

# %% [markdown]
# ## Part IV. Divide a text into tokens
#
# There are different ways to tokenize a text. Two examples from the **Natural Language Toolkit (nltk)** package are provided below:
#
# "Tokens" can be words, but also punctuation, sets of numbers, etc.

# %% [markdown]
# 9. **First**, let's try **nltk**'s **word_tokenize()** method.

# %%
tokens = nltk.word_tokenize(sotu1)
print(tokens[0:30]) #notice the difference between these tokens and "rawtokens" above
print(len(tokens))
# Out:
# ['Thank', 'you', 'very', 'much', '.', 'Mr.', 'Speaker', ',', 'Vice', 'President', 'Cheney', ',', 'Members', 'of', 'Congress', ',', 'distinguished', 'guests', ',', 'fellow', 'citizens', ':', 'As', 'we', 'gather', 'tonight', ',', 'our', 'Nation', 'is']
# 4352

# %% [markdown]
# 10. **Second**, NLTK offers another way to tokenize, but this time removing punctuation.

# %%
#another way to tokenize
from nltk import RegexpTokenizer  
tokenizer = RegexpTokenizer(r'\w+')
tokens=tokenizer.tokenize(sotu1)
print(tokens[:30])
print(len(tokens))
# Out:
# ['Thank', 'you', 'very', 'much', 'Mr', 'Speaker', 'Vice', 'President', 'Cheney', 'Members', 'of', 'Congress', 'distinguished', 'guests', 'fellow', 'citizens', 'As', 'we', 'gather', 'tonight', 'our', 'Nation', 'is', 'at', 'war', 'our', 'economy', 'is', 'in', 'recession']
# 3875

# %% [markdown]
# <h3 style="color:blue;">Exercises for Part IV</h3>
#
# <p style="color:blue;">10b. Tokenize your chosen sotu2 text using one of the above two methods.</p>

# %%
from nltk import RegexpTokenizer  
tokenizer = RegexpTokenizer(r'\w+')
tokens2=tokenizer.tokenize(sotu2)
print(tokens2[:30])
print(len(tokens2))
# Out:
# ['Fellow', 'Citizens', 'of', 'the', 'Senate', 'and', 'House', 'of', 'Representatives', 'Again', 'the', 'blessings', 'of', 'health', 'and', 'abundant', 'harvests', 'claim', 'our', 'profoundest', 'gratitude', 'to', 'Almighty', 'God', 'The', 'condition', 'of', 'our', 'foreign', 'affairs']
# 6121

# %% [markdown]
# ## V. Words Count / Word Counts
#
# 11. We can count the length of a text using the **len()** function. Run the following two lines of code below. What is the difference between the two?

# %%
print(len(sotu2))
print(len(tokens2))
# Out:
# 36164
# 6121

# %% [markdown]
# 12. We can create a frequency list of words in this State of the Union Address using the **Counter()** function from the Python **collections** library.

# %%
tokfreqs = collections.Counter(tokens)
tokfreqs.most_common(60)         #to view the 60 most common items in tokfreqs
#tokfreqs.most_common()[-100:]   #to view the 60 least common items in tokfreqs
# Out:
# [('and', 189),
#  ('the', 161),
#  ('of', 123),
#  ('to', 121),
#  ('in', 68),
#  ('our', 65),
#  ('a', 64),
#  ('we', 51),
#  ('will', 49),
#  ('is', 44),
#  ('We', 34),
#  ('I', 34),
#  ('America', 33),
#  ('have', 32),
#  ('on', 30),
#  ('that', 29),
#  ('for', 23),
#  ('be', 23),
#  ('with', 22),
#  ('this', 21),
#  ('it', 20),
#  ('world', 19),
#  ('And', 19),
#  ('s', 18),
#  ('must', 18),
#  ('who', 17),
#  ('their', 17),
#  ('are', 17),
#  ('these', 17),
#  ('security', 17),
#  ('American', 15),
#  ('not', 15),
#  ('as', 15),
#  ('at', 14),
#  ('people', 14),
#  ('from', 14),
#  ('Our', 14),
#  ('Afghanistan', 13),
#  ('terror', 13),
#  ('you', 12),
#  ('war', 12),
#  ('has', 12),
#  ('The', 12),
#  ('weapons', 12),
#  ('country', 11),
#  ('new', 11),
#  ('by', 11),
#  ('jobs', 11),
#  ('more', 11),
#  ('terrorist', 10),
#  ('so', 10),
#  ('freedom', 10),
#  ('was', 10),
#  ('Congress', 9),
#  ('citizens', 9),
#  ('Nation', 9),
#  ('terrorists', 9),
#  ('all', 9),
#  ('been', 8),
#  ('In', 8)]

# %% [markdown]
# 13, What do you notice? How can we make this frequency list more revealing?

# %% [markdown]
# **14. We can convert all the tokens to lower-case.**

# %%
ltokens = [tok.lower() for tok in tokens]
print("our tokens2 list converted to lower-case (saved as ltokens2) - contains",len(ltokens),"tokens.")
print(ltokens[:40])
# Out:
# our tokens2 list converted to lower-case (saved as ltokens2) - contains 3875 tokens.
# ['thank', 'you', 'very', 'much', 'mr', 'speaker', 'vice', 'president', 'cheney', 'members', 'of', 'congress', 'distinguished', 'guests', 'fellow', 'citizens', 'as', 'we', 'gather', 'tonight', 'our', 'nation', 'is', 'at', 'war', 'our', 'economy', 'is', 'in', 'recession', 'and', 'the', 'civilized', 'world', 'faces', 'unprecedented', 'dangers', 'yet', 'the', 'state']

# %% [markdown]
# **15. We often want to remove stopwords**. **Stop words** are common words that reveal little about the meaning of a text (such as articles like "the", conjunctions like "and", prepositions like "on", pronouns like "our", and helper verbs like "can"). Fortunately, NLTK provides a list of stop words in English (and other languages as well) that we can use to eliminate all such words from our texts.
#
# Let's examine stopwords in English:

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p style="color:green"><b>Code Together</b>: 16. What if you work with another language? Let's print out the language options for NLTK's stopwords:</p>
# </div>

# %%
# languages in nltk
print(stopwords.fileids())
# Out:
# ['arabic', 'azerbaijani', 'basque', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'turkish']

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p style="color:green">17. Now try to print out stopwords from a language of your choice (using the same code we used above to print out English stopwords):</p>
# </div>

# %%
print(stopwords.words('spanish'))
# Out:
# ['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los', 'del', 'se', 'las', 'por', 'un', 'para', 'con', 'no', 'una', 'su', 'al', 'lo', 'como', 'más', 'pero', 'sus', 'le', 'ya', 'o', 'este', 'sí', 'porque', 'esta', 'entre', 'cuando', 'muy', 'sin', 'sobre', 'también', 'me', 'hasta', 'hay', 'donde', 'quien', 'desde', 'todo', 'nos', 'durante', 'todos', 'uno', 'les', 'ni', 'contra', 'otros', 'ese', 'eso', 'ante', 'ellos', 'e', 'esto', 'mí', 'antes', 'algunos', 'qué', 'unos', 'yo', 'otro', 'otras', 'otra', 'él', 'tanto', 'esa', 'estos', 'mucho', 'quienes', 'nada', 'muchos', 'cual', 'poco', 'ella', 'estar', 'estas', 'algunas', 'algo', 'nosotros', 'mi', 'mis', 'tú', 'te', 'ti', 'tu', 'tus', 'ellas', 'nosotras', 'vosotros', 'vosotras', 'os', 'mío', 'mía', 'míos', 'mías', 'tuyo', 'tuya', 'tuyos', 'tuyas', 'suyo', 'suya', 'suyos', 'suyas', 'nuestro', 'nuestra', 'nuestros', 'nuestras', 'vuestro', 'vuestra', 'vuestros', 'vuestras', 'esos', 'esas', 'estoy', 'estás', 'está', 'estamos', 'estáis', 'están', 'esté', 'estés', 'estemos', 'estéis', 'estén', 'estaré', 'estarás', 'estará', 'estaremos', 'estaréis', 'estarán', 'estaría', 'estarías', 'estaríamos', 'estaríais', 'estarían', 'estaba', 'estabas', 'estábamos', 'estabais', 'estaban', 'estuve', 'estuviste', 'estuvo', 'estuvimos', 'estuvisteis', 'estuvieron', 'estuviera', 'estuvieras', 'estuviéramos', 'estuvierais', 'estuvieran', 'estuviese', 'estuvieses', 'estuviésemos', 'estuvieseis', 'estuviesen', 'estando', 'estado', 'estada', 'estados', 'estadas', 'estad', 'he', 'has', 'ha', 'hemos', 'habéis', 'han', 'haya', 'hayas', 'hayamos', 'hayáis', 'hayan', 'habré', 'habrás', 'habrá', 'habremos', 'habréis', 'habrán', 'habría', 'habrías', 'habríamos', 'habríais', 'habrían', 'había', 'habías', 'habíamos', 'habíais', 'habían', 'hube', 'hubiste', 'hubo', 'hubimos', 'hubisteis', 'hubieron', 'hubiera', 'hubieras', 'hubiéramos', 'hubierais', 'hubieran', 'hubiese', 'hubieses', 'hubiésemos', 'hubieseis', 'hubiesen', 'habiendo', 'habido', 'habida', 'habidos', 'habidas', 'soy', 'eres', 'es', 'somos', 'sois', 'son', 'sea', 'seas', 'seamos', 'seáis', 'sean', 'seré', 'serás', 'será', 'seremos', 'seréis', 'serán', 'sería', 'serías', 'seríamos', 'seríais', 'serían', 'era', 'eras', 'éramos', 'erais', 'eran', 'fui', 'fuiste', 'fue', 'fuimos', 'fuisteis', 'fueron', 'fuera', 'fueras', 'fuéramos', 'fuerais', 'fueran', 'fuese', 'fueses', 'fuésemos', 'fueseis', 'fuesen', 'sintiendo', 'sentido', 'sentida', 'sentidos', 'sentidas', 'siente', 'sentid', 'tengo', 'tienes', 'tiene', 'tenemos', 'tenéis', 'tienen', 'tenga', 'tengas', 'tengamos', 'tengáis', 'tengan', 'tendré', 'tendrás', 'tendrá', 'tendremos', 'tendréis', 'tendrán', 'tendría', 'tendrías', 'tendríamos', 'tendríais', 'tendrían', 'tenía', 'tenías', 'teníamos', 'teníais', 'tenían', 'tuve', 'tuviste', 'tuvo', 'tuvimos', 'tuvisteis', 'tuvieron', 'tuviera', 'tuvieras', 'tuviéramos', 'tuvierais', 'tuvieran', 'tuviese', 'tuvieses', 'tuviésemos', 'tuvieseis', 'tuviesen', 'teniendo', 'tenido', 'tenida', 'tenidos', 'tenidas', 'tened']

# %% [markdown]
# 18. Next, with our English stopwords list, we can further modify our ltokens list by removing stopwords:

# %%
stop = stopwords.words('english')
stop = sorted(stop)
ltokens_ns = [tok for tok in ltokens if tok not in stop]        #list comprehension removes all stopwords from ltokens2

print("We had",len(ltokens),"tokens in our ltoken2 list.")
print("beginning with:",ltokens[:30]," \n")
print("After removing stop words, we now have",len(ltokens_ns),"tokens in our list.")
print("beginning with:",ltokens_ns[:30])
# Out:
# We had 3875 tokens in our ltoken2 list.
# beginning with: ['thank', 'you', 'very', 'much', 'mr', 'speaker', 'vice', 'president', 'cheney', 'members', 'of', 'congress', 'distinguished', 'guests', 'fellow', 'citizens', 'as', 'we', 'gather', 'tonight', 'our', 'nation', 'is', 'at', 'war', 'our', 'economy', 'is', 'in', 'recession']
#
# After removing stop words, we now have 2098 tokens in our list.
# beginning with: ['thank', 'much', 'mr', 'speaker', 'vice', 'president', 'cheney', 'members', 'congress', 'distinguished', 'guests', 'fellow', 'citizens', 'gather', 'tonight', 'nation', 'war', 'economy', 'recession', 'civilized', 'world', 'faces', 'unprecedented', 'dangers', 'yet', 'state', 'union', 'never', 'stronger', 'last']

# %% [markdown]
# 19. We can then count the frequencies of words in this token list using the **Counter** function from the **collections** library we imported at the top of this notebook.

# %%
tokfreqs = collections.Counter(ltokens_ns)
tokfreqs.most_common(10)
# Out:
# [('america', 33),
#  ('world', 19),
#  ('security', 19),
#  ('must', 18),
#  ('american', 15),
#  ('people', 14),
#  ('freedom', 14),
#  ('new', 13),
#  ('afghanistan', 13),
#  ('terror', 13)]

# %% [markdown]
# <div class="alert alert-success" role="alert">
#     <p style="color:green"><b>Code Together</b>:</p>
#     <p style="color:green">20. Using your chosen <b>sotu2</b> address:</p>
#     <ol style="color:green">
#         <li>tokenize it</li>
#         <li>lower-case it</li>
#         <li>remove all stopwords</li>
#         <li>create a frequency count of the words in this address</li>
#         <li>identify the 30 most frequent tokens (with stopwords removed).</li>
#     </ol>
# </div>

# %% [markdown]
# ## VI. Ngrams

# %% [markdown]
# What if we want to examine the frequency of multiple-word terms and phrases?
#
# Instead of splitting texts into words, we can split them into bigrams (two-word combinations), trigrams (three-word combinations), and other *n*grams (terms with *n* number of words).
#
# A great tool for examining the frequency of ngrams over time is [Google's Ngram Viewer.](https://books.google.com/ngrams/) Click on this link and try some different combinations.
#
# <!--<h1>
#     <img src = "C:\Users\F0040RP\Documents\Website\images\textAnalysis\google_ngrams_history_subfields.png" style = "width: 80%">
#     <img src = "https://books.google.com/ngrams/graph?content=cultural+history%2Cpolitical+history%2Cintellectual+history%2Cmicrohistory%2C+women%27s+history&year_start=1800&year_end=2019&corpus=en-2019&smoothing=3" style="width:80%;">
# </h1>-->

# %% [markdown]
# 21. To create, count, and analyze ngrams from our own texts and corpora, we can use **NLTK**'s **ngrams** function, which reads in a list of tokens and the number of words we want per combination. For example:

# %%
n = 2
bigrams = list(nltk.ngrams(["to", "be", ",", "or", "not", "to", "be", ",", "that", "is", "the", "question", "."], n))
print(bigrams)
# Out:
# [('to', 'be'), ('be', ','), (',', 'or'), ('or', 'not'), ('not', 'to'), ('to', 'be'), ('be', ','), (',', 'that'), ('that', 'is'), ('is', 'the'), ('the', 'question'), ('question', '.')]

# %%
collections.Counter(bigrams)
# Out:
# Counter({('to', 'be'): 2,
#          ('be', ','): 2,
#          (',', 'or'): 1,
#          ('or', 'not'): 1,
#          ('not', 'to'): 1,
#          (',', 'that'): 1,
#          ('that', 'is'): 1,
#          ('is', 'the'): 1,
#          ('the', 'question'): 1,
#          ('question', '.'): 1})

# %%
n = 2
n_grams=list(nltk.ngrams(ltokens_ns,n))
print(n_grams)
# Out:
# [('thank', 'much'), ('much', 'mr'), ('mr', 'speaker'), ('speaker', 'vice'), ('vice', 'president'), ('president', 'cheney'), ('cheney', 'members'), ('members', 'congress'), ('congress', 'distinguished'), ('distinguished', 'guests'), ('guests', 'fellow'), ('fellow', 'citizens'), ('citizens', 'gather'), ('gather', 'tonight'), ('tonight', 'nation'), ('nation', 'war'), ('war', 'economy'), ('economy', 'recession'), ('recession', 'civilized'), ('civilized', 'world'), ('world', 'faces'), ('faces', 'unprecedented'), ('unprecedented', 'dangers'), ('dangers', 'yet'), ('yet', 'state'), ('state', 'union'), ('union', 'never'), ('never', 'stronger'), ('stronger', 'last'), ('last', 'met'), ('met', 'hour'), ('hour', 'shock'), ('shock', 'suffering'), ('suffering', '4'), ('4', 'short'), ('short', 'months'), ('months', 'nation'), ('nation', 'comforted'), ('comforted', 'victims'), ('victims', 'begun'), ('begun', 'rebuild'), ('rebuild', 'new'), ('new', 'york'), ('york', 'pentagon'), ('pentagon', 'rallied'), ('rallied', 'great'), ('great', 'coalition'), ('coalition', 'captured'), ('captured', 'arrested'), ('arrested', 'rid'), ('rid', 'world'), ('world', 'thousands'), ('thousands', 'terrorists'), ('terrorists', 'destroyed'), ('destroyed', 'afghanistan'), ('afghanistan', 'terrorist'), ('terrorist', 'training'), ('training', 'camps'), ('camps', 'saved'), ('saved', 'people'), ('people', 'starvation'), ('starvation', 'freed'), ('freed', 'country'), ('country', 'brutal'), ('brutal', 'oppression'), ('oppression', 'american'), ('american', 'flag'), ('flag', 'flies'), ('flies', 'embassy'), ('embassy', 'kabul'), ('kabul', 'terrorists'), ('terrorists', 'occupied'), ('occupied', 'afghanistan'), ('afghanistan', 'occupy'), ('occupy', 'cells'), ('cells', 'guantanamo'), ('guantanamo', 'bay'), ('bay', 'terrorist'), ('terrorist', 'leaders'), ('leaders', 'urged'), ('urged', 'followers'), ('followers', 'sacrifice'), ('sacrifice', 'lives'), ('lives', 'running'), ('running', 'america'), ('america', 'afghanistan'), ('afghanistan', 'allies'), ('allies', 'terror'), ('terror', 'partners'), ('partners', 'rebuilding'), ('rebuilding', 'country'), ('country', 'evening'), ('evening', 'welcomed'), ('welcomed', 'distinguished'), ('distinguished', 'interim'), ('interim', 'leader'), ('leader', 'liberated'), ('liberated', 'afghanistan'), ('afghanistan', 'chairman'), ('chairman', 'hamid'), ('hamid', 'karzai'), ('karzai', 'last'), ('last', 'time'), ('time', 'met'), ('met', 'chamber'), ('chamber', 'mothers'), ('mothers', 'daughters'), ('daughters', 'afghanistan'), ('afghanistan', 'captives'), ('captives', 'homes'), ('homes', 'forbidden'), ('forbidden', 'working'), ('working', 'going'), ('going', 'school'), ('school', 'today'), ('today', 'women'), ('women', 'free'), ('free', 'part'), ('part', 'afghanistan'), ('afghanistan', 'new'), ('new', 'government'), ('government', 'welcome'), ('welcome', 'new'), ('new', 'minister'), ('minister', 'women'), ('women', 'affairs'), ('affairs', 'dr'), ('dr', 'sima'), ('sima', 'samar'), ('samar', 'progress'), ('progress', 'tribute'), ('tribute', 'spirit'), ('spirit', 'afghan'), ('afghan', 'people'), ('people', 'resolve'), ('resolve', 'coalition'), ('coalition', 'might'), ('might', 'united'), ('united', 'states'), ('states', 'military'), ('military', 'called'), ('called', 'troops'), ('troops', 'action'), ('action', 'complete'), ('complete', 'confidence'), ('confidence', 'courage'), ('courage', 'skill'), ('skill', 'tonight'), ('tonight', 'thanks'), ('thanks', 'winning'), ('winning', 'war'), ('war', 'terror'), ('terror', 'men'), ('men', 'women'), ('women', 'armed'), ('armed', 'forces'), ('forces', 'delivered'), ('delivered', 'message'), ('message', 'clear'), ('clear', 'every'), ('every', 'enemy'), ('enemy', 'united'), ('united', 'states'), ('states', 'even'), ('even', '7'), ('7', '000'), ('000', 'miles'), ('miles', 'away'), ('away', 'across'), ('across', 'oceans'), ('oceans', 'continents'), ('continents', 'mountaintops'), ('mountaintops', 'caves'), ('caves', ' ...

# %%
collections.Counter(n_grams).most_common()
# Out:
# [(('united', 'states'), 6),
#  (('september', '11th'), 5),
#  (('good', 'jobs'), 5),
#  (('war', 'terror'), 4),
#  (('weapons', 'mass'), 4),
#  (('mass', 'destruction'), 4),
#  (('american', 'people'), 4),
#  (('must', 'act'), 4),
#  (('homeland', 'security'), 4),
#  (('freedom', 'corps'), 4),
#  (('training', 'camps'), 3),
#  (('men', 'women'), 3),
#  (('throughout', 'world'), 3),
#  (('america', 'allies'), 3),
#  (('win', 'war'), 3),
#  (('war', 'protect'), 3),
#  (('create', 'jobs'), 3),
#  (('economic', 'security'), 3),
#  (('ask', 'congress'), 3),
#  (('tax', 'relief'), 3),
#  (('usa', 'freedom'), 3),
#  (('civilized', 'world'), 2),
#  (('new', 'york'), 2),
#  (('last', 'time'), 2),
#  (('armed', 'forces'), 2),
#  (('nation', 'many'), 2),
#  (('tens', 'thousands'), 2),
#  (('terrorist', 'camps'), 2),
#  (('nuclear', 'weapons'), 2),
#  (('friends', 'allies'), 2),
#  (('destruction', 'regimes'), 2),
#  (('people', 'hope'), 2),
#  (('must', 'always'), 2),
#  (('protect', 'homeland'), 2),
#  (('congress', 'join'), 2),
#  (('america', 'must'), 2),
#  (('republicans', 'democrats'), 2),
#  (('priority', 'budget'), 2),
#  (('police', 'fire'), 2),
#  (('fire', 'departments'), 2),
#  (('american', 'workers'), 2),
#  (('proud', 'work'), 2),
#  (('jobs', 'depend'), 2),
#  (('thought', 'tax'), 2),
#  (('people', 'responded'), 2),
#  (('every', 'american'), 2),
#  (('social', 'security'), 2),
#  (('ask', 'join'), 2),
#  (('hope', 'join'), 2),
#  (('join', 'new'), 2),
#  (('america', 'needs'), 2),
#  (('needs', 'citizens'), 2),
#  (('islamic', 'world'), 2),
#  (('moment', 'opportunity'), 2),
#  (('thank', 'much'), 1),
#  (('much', 'mr'), 1),
#  (('mr', 'speaker'), 1),
#  (('speaker', 'vice'), 1),
#  (('vice', 'president'), 1),
#  (('president', 'cheney'), 1),
#  (('cheney', 'members'), 1),
#  (('members', 'congress'), 1),
#  (('congress', 'distinguished'), 1),
#  (('distinguished', 'guests'), 1),
#  (('guests', 'fellow'), 1),
#  (('fellow', 'citizens'), 1),
#  (('citizens', 'gather'), 1),
#  (('gather', 'tonight'), 1),
#  (('tonight', 'nation'), 1),
#  (('nation', 'war'), 1),
#  (('war', 'economy'), 1),
#  (('economy', 'recession'), 1),
#  (('recession', 'civilized'), 1),
#  (('world', 'faces'), 1),
#  (('faces', 'unprecedented'), 1),
#  (('unprecedented', 'dangers'), 1),
#  (('dangers', 'yet'), 1),
#  (('yet', 'state'), 1),
#  (('state', 'union'), 1),
#  (('union', 'never'), 1),
#  (('never', 'stronger'), 1),
#  (('stronger', 'last'), 1),
#  (('last', 'met'), 1),
#  (('met', 'hour'), 1),
#  (('hour', 'shock'), 1),
#  (('shock', 'suffering'), 1),
#  (('suffering', '4'), 1),
#  (('4', 'short'), 1),
#  (('short', 'months'), 1),
#  (('months', 'nation'), 1),
#  (('nation', 'comforted'), 1),
#  (('comforted', 'victims'), 1),
#  (('victims', 'begun'), 1),
#  (('begun', 'rebuild'), 1),
#  (('rebuild', 'new'), 1),
#  (('york', 'pentagon'), 1),
#  (('pentagon', 'rallied'), 1),
#  (('rallied', 'great'), 1),
#  (('great', 'coalition'), 1),
#  (('coalition', 'captured'), 1),
#  (('captured', 'arrested'), 1),
#  (('arrested', 'rid'), 1),
#  (('rid', 'world'), 1),
#  (('world', 'thousands'), 1),
#  (('thousands', 'terrorists'), 1),
#  (('terrorists', 'destroyed'), 1),
#  (('destroyed', 'afghanistan'), 1),
#  (('afghanistan', 'terrorist'), 1),
#  (('terrorist', 'training'), 1),
#  (('camps', 'saved'), 1),
#  (('saved', 'people'), 1),
#  (('people', 'starvation'), 1),
#  (('starvation', 'freed'), 1),
#  (('freed', 'country'), 1),
#  (('country', 'brutal'), 1),
#  (('brutal', 'oppression'), 1),
#  (('oppression', 'american'), 1),
#  (('american', 'flag'), 1),
#  (('flag', 'flies'), 1),
#  (('flies', 'embassy'), 1),
#  (('embassy', 'kabul'), 1),
#  (('kabul', 'terrorists'), 1),
#  (('terrorists', 'occupied'), 1),
#  (('occupied', 'afghanistan'), 1),
#  (('afghanistan', 'occupy'), 1),
#  (('occupy', 'cells'), 1),
#  (('cells', 'guantanamo'), 1),
#  (('guantanamo', 'bay'), 1),
#  (('bay', 'terrorist'), 1),
#  (('terrorist', 'leaders'), 1),
#  (('leaders', 'urged'), 1),
#  (('urged', 'followers'), 1),
#  (('followers', 'sacrifice'), 1),
#  (('sacrifice', 'lives'), 1),
#  (('lives', 'running'), 1),
#  (('running', 'america'), 1),
#  (('america', 'afghanistan'), 1),
#  (('afghanistan', 'allies'), 1),
#  (('allies', 'terror'), 1),
#  (('terror', 'partners'), 1),
#  (('partners', 'rebuilding'), 1),
#  (('rebuilding', 'country'), 1),
#  (('country', 'evening'), 1),
#  (('evening', 'welcomed'), 1),
#  (('welcomed', 'distinguished'), 1),
#  (('distinguished', 'interim'), 1),
#  (('interim', 'leader'), 1),
#  (('leader', 'liberated'), 1),
#  (('liberated', 'afghanistan'), 1),
#  (('afghanistan', 'chairman'), 1),
#  (('chairman', 'hamid'), 1),
#  (('hamid', 'karzai'), 1),
#  (('karzai', 'last'), 1),
#  (('time', 'met'), 1),
#  (('met', 'chamber'), 1),
#  (('chamber', 'mothers'), 1),
#  (('mothers', 'daughters'), 1),
#  (('daughters', 'afghanistan'), 1),
#  (('afghanistan', 'captives'), 1),
#  (('captives', 'homes'), 1),
#  (('homes', 'forbidden'), 1),
#  (('forbidden', 'working'), 1),
#  (('working', 'going'), 1),
#  (('going', 'school'), 1),
#  (('school', 'today'), 1),
#  (('today', 'women'), 1),
#  (('women', 'free'), 1),
#  (('free', 'part'), 1),
#  (('part', 'afghanistan'), 1),
#  (('afghanistan', 'new'), 1),
#  (('new', 'government'), 1),
#  (('government', 'welcome'), 1),
#  (('welcome', 'new'), 1),
#  (('new', 'minister'), 1),
#  (('minister', 'women'), 1),
#  (('women', 'affairs'), 1),
#  (('affairs', 'dr'), 1),
#  (('dr', 'sima'), 1),
#  (('sima', 'samar'), 1),
#  (('samar', 'progress'), 1),
#  (('progress', 'tribute'), 1),
#  (('tribute', 'spirit'), 1),
#  (('spirit', 'afghan'), 1),
#  (('afghan', 'people'), 1),
#  (('people', 'resolve'), 1),
#  (('resolve', 'coalition'), 1),
#  (('coalition', 'might'), 1),
#  (('might', 'united'), 1),
#  (('states', 'military'), 1),
#  (('military', 'called'), 1),
#  (('called', 'troops'), 1),
#  (('troops', 'action'), 1),
#  (('action', 'complete'), 1),
#  (('complete', 'confidence'), 1),
#  (('confidence', 'courage'), 1),
#  (('courage', 'skill'), 1),
#  (('skill', 'tonight'), 1),
#  (('tonight', 'thanks'), 1),
#  (('thanks', 'winning'), 1),
#  (('winning', 'war'), 1),
#  (('terror', 'men'), 1),
#  (('women', 'armed'), 1),
#  (('forces', 'delivered'), 1),
#  (('delivered', 'message'), 1),
#  (('message', 'clear'), 1),
#  (('clear', 'every'), 1),
#  (('every', 'enemy'), 1),
#  (('enemy', 'united'), 1),
#  (('states', 'even'), 1),
#  (('even', '7'), 1),
#  (('7', '000'), 1),
#  (('000', 'miles'), 1),
#  (('miles', 'away'), 1),
#  (('away', 'across'), 1),
#  (('across', 'oceans'), 1),
#  (('oceans', 'continents'), 1),
#  (('continents', 'mountaintops'), 1),
#  (('mountaintops', 'caves'), 1),
#  (('caves', 'escape'), 1),
#  (('escape', 'justice'), 1),
#  (('justice', 'nation'), 1),
#  (('many', 'americans'), 1),
#  (('americans', '4'), 1),
#  (('4', 'months'), 1),
#  (('months', 'brought'), 1),
#  (('brought', 'sorrow'), 1),
#  (('sorrow', 'pain'), 1),
#  (('pain', 'never'), 1),
#  (('never', 'completely'), 1),
#  (('completely', 'go'), 1),
#  (('go', 'away'), 1),
#  (('away', 'every'), 1),
#  (('every', 'day'), 1),
#  (('day', 'retired'), 1),
#  (('retired', 'firefighter'), 1),
#  (('firefighter', 'returns'), 1),
#  (('returns', 'ground'), 1),
#  (('ground', 'zero'), 1),
#  (('zero', 'feel'), 1),
#  (('feel', 'closer'), 1),
#  (('closer', 'two'), 1),
#  (('two', 'sons'), 1),
#  (('sons', 'died'), 1),
#  (('died', 'memorial'), 1),
#  (('memorial', 'new'), 1),
#  (('york', 'little'), 1),
#  (('little', 'boy'), 1),
#  (('boy', 'left'), 1),
#  (('left', 'football'), 1),
#  (('football', 'note'), 1),
#  (('note', 'lost'), 1),
#  (('lost', 'father'), 1),
#  (('father', 'dear'), 1),
#  (('dear', 'daddy'), 1),
#  (('daddy', 'please'), 1),
#  (('please', 'take'), 1),
#  (('take', 'heaven'), 1),
#  (('heaven', 'want'), 1),
#  (('want', 'play'), 1),
#  (('play', 'football'), 1),
#  (('football', 'play'), 1),
#  (('play', 'day'), 1),
#  (('day', 'last'), 1),
#  (('last', 'month'), 1),
#  (('month', 'grave'), 1),
#  (('grave', 'husband'), 1),
#  (('husband', 'micheal'), 1),
#  (('micheal', 'cia'), 1),
#  (('cia', 'officer'), 1),
#  (('officer', 'marine'), 1),
#  (('marine', 'died'), 1),
#  (('died', 'mazar'), 1),
#  (('mazar', 'e'), 1),
#  (('e', 'sharif'), 1),
#  (('sharif', 'shannon'), 1),
#  (('shannon', 'spann'), 1),
#  (('spann', 'said'), 1),
#  (('said', 'words'), 1),
#  (('words', 'farewell'), 1),
#  (('farewell', 'semper'), 1),
#  (('semper', 'fi'), 1),
#  (('fi', 'love'), 1),
#  (('love', 'shannon'), 1),
#  (('shannon', 'us'), 1),
#  (('us', 'tonight'), 1),
#  (('tonight', 'shannon'), 1),
#  (('shannon', 'assure'), 1),
#  (('assure', 'lost'), 1),
#  (('lost', 'loved'), 1),
#  (('loved', 'one'), 1),
#  (('one', 'cause'), 1),
#  (('cause', 'country'), 1),
#  (('country', 'never'), 1),
#  (('never', 'forget'), 1),
#  (('forget', 'debt'), 1),
#  (('debt', 'owe'), 1),
#  (('owe', 'michael'), 1),
#  (('michael', 'gave'), 1),
#  (('gave', 'lives'), 1),
#  (('lives', 'freedom'), 1),
#  (('freedom', 'cause'), 1),
#  (('cause', 'continues'), 1),
#  (('continues', 'discoveries'), 1),
#  (('discoveries', 'afghanistan'), 1),
#  (('afghanistan', 'confirmed'), 1),
#  (('confirmed', 'worst'), 1),
#  (('worst', 'fears'), 1),
#  (('fears', 'showed'), 1),
#  (('showed', 'us'), 1),
#  (('us', 'true'), 1),
#  (('true', 'scope'), 1),
#  (('scope', 'task'), 1),
#  (('task', 'ahead'), 1),
#  (('ahead', 'seen'), 1),
#  (('seen', 'depth'), 1),
#  (('depth', 'enemies'), 1),
#  (('enemies', 'hatred'), 1),
#  (('hatred', 'videos'), 1),
#  (('videos', 'laugh'), 1),
#  (('laugh', 'loss'), 1),
#  (('loss', 'innocent'), 1),
#  (('innocent', 'life'), 1),
#  (('life', 'depth'), 1),
#  (('depth', 'hatred'), 1),
#  (('hatred', 'equaled'), 1),
#  (('equaled', 'madness'), 1),
#  (('madness', 'destruction'), 1),
#  (('destruction', 'design'), 1),
#  (('design', 'found'), 1),
#  (('found', 'diagrams'), 1),
#  (('diagrams', 'american'), 1),
#  (('american', 'nuclear'), 1),
#  (('nuclear', 'powerplants'), 1),
#  (('powerplants', 'public'), 1),
#  (('public', 'water'), 1),
#  (('water', 'facilities'), 1),
#  (('facilities', 'detailed'), 1),
#  (('detailed', 'instructions'), 1),
#  (('instructions', 'making'), 1),
#  (('making', 'chemical'), 1),
#  (('chemical', 'weapons'), 1),
#  (('weapons', 'surveillance'), 1),
#  (('surveillance', 'maps'), 1),
#  (('maps', 'american'), 1),
#  (('american', 'cities'), 1),
#  (('cities', 'thorough'), 1),
#  (('thorough', 'descriptions'), 1),
#  (('descriptions', 'landmarks'), 1),
#  (('landmarks', 'america'), 1),
#  (('america', 'throughout'), 1),
#  (('world', 'found'), 1),
#  (('found', 'afghanistan'), 1),
#  (('afghanistan', 'confirms'), 1),
#  (('confirms', 'far'), 1),
#  (('far', 'ending'), 1),
#  (('ending', 'war'), 1),
#  (('terror', 'beginning'), 1),
#  (('beginning', '19'), 1),
#  (('19', 'men'), 1),
#  (('men', 'hijacked'), 1),
#  (('hijacked', 'planes'), 1),
#  (('planes', 'september'), 1),
#  (('11th', 'trained'), 1),
#  (('trained', 'afghanistan'), 1),
#  (('afghanistan', 'camps'), 1),
#  (('camps', 'tens'), 1),
#  (('thousands', 'others'), 1),
#  (('others', 'thousands'), 1),
#  (('thousands', 'dangerous'), 1),
#  (('dangerous', 'killers'), 1),
#  (('killers', 'schooled'), 1),
#  (('schooled', 'methods'), 1),
#  (('methods', 'murder'), 1),
#  (('murder', 'often'), 1),
#  (('often', 'supported'), 1),
#  (('supported', 'outlaw'), 1),
#  (('outlaw', 'regimes'), 1),
#  (('regimes', 'spread'), 1),
#  (('spread', 'throughout'), 1),
#  (('world', 'like'), 1),
#  (('like', 'ticking'), 1),
#  (('ticking', 'timebombs'), 1),
#  (('timebombs', 'set'), 1),
#  (('set', 'go'), 1),
#  (('go', 'without'), 1),
#  (('without', 'warning'), 1),
#  (('warning', 'thanks'), 1),
#  (('thanks', 'work'), 1),
#  (('work', 'law'), 1),
#  (('law', 'enforcement'), 1),
#  (('enforcement', 'officials'), 1),
#  (('officials', 'coalition'), 1),
#  (('coalition', 'partners'), 1),
#  (('partners', 'hundreds'), 1),
#  (('hundreds', 'terrorists'), 1),
#  (('terrorists', 'arrested'), 1),
#  (('arrested', 'yet'), 1),
#  (('yet', 'tens'), 1),
#  (('thousands', 'trained'), 1),
#  (('trained', 'terrorists'), 1),
#  (('terrorists', 'still'), 1),
#  (('still', 'large'), 1),
#  (('large', 'enemies'), 1),
#  (('enemies', 'view'), 1),
#  (('view', 'entire'), 1),
#  (('entire', 'world'), 1),
#  (('world', 'battlefield'), 1),
#  (('battlefield', 'must'), 1),
#  (('must', 'pursue'), 1),
#  (('pursue', 'wherever'), 1),
#  (('wherever', 'long'), 1),
#  (('long', 'training'), 1),
#  (('camps', 'operate'), 1),
#  (('operate', 'long'), 1),
#  (('long', 'nations'), 1),
#  (('nations', 'harbor'), 1),
#  (('harbor', 'terrorists'), 1),
#  (('terrorists', 'freedom'), 1),
#  (('freedom', 'risk'), 1),
#  (('risk', 'america'), 1),
#  (('allies', 'must'), 1),
#  (('must', 'allow'), 1),
#  (('allow', 'nation'), 1),
#  (('nation', 'continue'), 1),
#  (('continue', 'steadfast'), 1),
#  (('steadfast', 'patient'), 1),
#  (('patient', 'persistent'), 1),
#  (('persistent', 'pursuit'), 1),
#  (('pursuit', 'two'), 1),
#  (('two', 'great'), 1),
#  (('great', 'objectives'), 1),
#  (('objectives', 'first'), 1),
#  (('first', 'shut'), 1),
#  (('shut', 'terrorist'), 1),
#  (('camps', 'disrupt'), 1),
#  (('disrupt', 'terrorist'), 1),
#  (('terrorist', 'plans'), 1),
#  (('plans', 'bring'), 1),
#  (('bring', 'terrorists'), 1),
#  (('terrorists', 'justice'), 1),
#  (('justice', 'second'), 1),
#  (('second', 'must'), 1),
#  (('must', 'prevent'), 1),
#  (('prevent', 'terrorists'), 1),
#  (('terrorists', 'regimes'), 1),
#  (('regimes', 'seek'), 1),
#  (('seek', 'chemical'), 1),
#  (('chemical', 'biological'), 1),
#  (('biological', 'nuclear'), 1),
#  (('weapons', 'threatening'), 1),
#  (('threatening', 'united'), 1),
#  (('states', 'world'), 1),
#  (('world', 'military'), 1),
#  (('military', 'put'), 1),
#  (('put', 'terror'), 1),
#  (('terror', 'training'), 1),
#  (('camps', 'afghanistan'), 1),
#  (('afghanistan', 'business'), 1),
#  (('business', 'yet'), 1),
#  (('yet', 'camps'), 1),
#  (('camps', 'still'), 1),
#  (('still', 'exist'), 1),
#  (('exist', 'least'), 1),
#  (('least', 'dozen'), 1),
#  (('dozen', 'countries'), 1),
#  (('countries', 'terrorist'), 1),
#  (('terrorist', 'underworld'), 1),
#  (('underworld', 'including'), 1),
#  (('including', 'groups'), 1),
#  (('groups', 'like'), 1),
#  (('like', 'hamas'), 1),
#  (('hamas', 'hizballah'), 1),
#  (('hizballah', 'islamic'), 1),
#  (('islamic', 'jihad'), 1),
#  (('jihad', 'jaish'), 1),
#  (('jaish', 'e'), 1),
#  (('e', 'mohammed'), 1),
#  (('mohammed', 'operates'), 1),
#  (('operates', 'remote'), 1),
#  (('remote', 'jungles'), 1),
#  (('jungles', 'deserts'), 1),
#  (('deserts', 'hides'), 1),
#  (('hides', 'centers'), 1),
#  (('centers', 'large'), 1),
#  (('large', 'cities'), 1),
#  (('cities', 'visible'), 1),
#  (('visible', 'military'), 1),
#  (('military', 'action'), 1),
#  (('action', 'afghanistan'), 1),
#  (('afghanistan', 'america'), 1),
#  (('america', 'acting'), 1),
#  (('acting', 'elsewhere'), 1),
#  (('elsewhere', 'troops'), 1),
#  (('troops', 'philippines'), 1),
#  (('philippines', 'helping'), 1),
#  (('helping', 'train'), 1),
#  (('train', 'country'), 1),
#  (('country', 'armed'), 1),
#  (('forces', 'go'), 1),
#  (('go', 'terrorist'), 1),
#  (('terrorist', 'cells'), 1),
#  (('cells', 'executed'), 1),
#  (('executed', 'american'), 1),
#  (('american', 'still'), 1),
#  (('still', 'hold'), 1),
#  (('hold', 'hostages'), 1),
#  (('hostages', 'soldiers'), 1),
#  (('soldiers', 'working'), 1),
#  (('working', 'bosnian'), 1),
#  (('bosnian', 'government'), 1),
#  (('government', 'seized'), 1),
#  (('seized', 'terrorists'), 1),
#  (('terrorists', 'plotting'), 1),
#  (('plotting', 'bomb'), 1),
#  (('bomb', 'embassy'), 1),
#  (('embassy', 'navy'), 1),
#  (('navy', 'patrolling'), 1),
#  (('patrolling', 'coast'), 1),
#  (('coast', 'africa'), 1),
#  (('africa', 'block'), 1),
#  (('block', 'shipment'), 1),
#  (('shipment', 'weapons'), 1),
#  (('weapons', 'establishment'), 1),
#  (('establishment', 'terrorist'), 1),
#  (('camps', 'somalia'), 1),
#  (('somalia', 'hope'), 1),
#  (('hope', 'nations'), 1),
#  (('nations', 'heed'), 1),
#  (('heed', 'call'), 1),
#  (('call', 'eliminate'), 1),
#  (('eliminate', 'terrorist'), 1),
#  (('terrorist', 'parasites'), 1),
#  (('parasites', 'threaten'), 1),
#  (('threaten', 'countries'), 1),
#  (('countries', 'many'), 1),
#  (('many', 'nations'), 1),
#  (('nations', 'acting'), 1),
#  (('acting', 'forcefully'), 1),
#  (('forcefully', 'pakistan'), 1),
#  (('pakistan', 'cracking'), 1),
#  (('cracking', 'terror'), 1),
#  (('terror', 'admire'), 1),
#  (('admire', 'strong'), 1),
#  (('strong', 'leadership'), 1),
#  (('leadership', 'president'), 1),
#  (('president', 'musharraf'), 1),
#  (('musharraf', 'governments'), 1),
#  (('governments', 'timid'), 1),
#  (('timid', 'face'), 1),
#  (('face', 'terror'), 1),
#  (('terror', 'make'), 1),
#  (('make', 'mistake'), 1),
#  (('mistake', 'act'), 1),
#  (('act', 'america'), 1),
#  (('america', 'second'), 1),
#  (('second', 'goal'), 1),
#  (('goal', 'prevent'), 1),
#  (('prevent', 'regimes'), 1),
#  (('regimes', 'sponsor'), 1),
#  (('sponsor', 'terror'), 1),
#  (('terror', 'threatening'), 1),
#  (('threatening', 'america'), 1),
#  (('america', 'friends'), 1),
#  (('allies', 'weapons'), 1),
#  (('regimes', 'pretty'), 1),
#  (('pretty', 'quiet'), 1),
#  (('quiet', 'since'), 1),
#  (('since', 'september'), 1),
#  (('11th', 'know'), 1),
#  (('know', 'true'), 1),
#  (('true', 'nature'), 1),
#  (('nature', 'north'), 1),
#  (('north', 'korea'), 1),
#  (('korea', 'regime'), 1),
#  (('regime', 'arming'), 1),
#  (('arming', 'missiles'), 1),
#  (('missiles', 'weapons'), 1),
#  (('destruction', 'starving'), 1),
#  (('starving', 'citizens'), 1),
#  (('citizens', 'iran'), 1),
#  (('iran', 'aggressively'), 1),
#  (('aggressively', 'pursues'), 1),
#  (('pursues', 'weapons'), 1),
#  (('weapons', 'exports'), 1),
#  (('exports', 'terror'), 1),
#  (('terror', 'unelected'), 1),
#  (('unelected', 'repress'), 1),
#  (('repress', 'iranian'), 1),
#  (('iranian', 'people'), 1),
#  (('hope', 'freedom'), 1),
#  (('freedom', 'iraq'), 1),
#  (('iraq', 'continues'), 1),
#  (('continues', 'flaunt'), 1),
#  (('flaunt', 'hostility'), 1),
#  (('hostility', 'toward'), 1),
#  (('toward', 'america'), 1),
#  (('america', 'support'), 1),
#  (('support', 'terror'), 1),
#  (('terror', 'iraqi'), 1),
#  (('iraqi', 'regime'), 1),
#  (('regime', 'plotted'), 1),
#  (('plotted', 'develop'), 1),
#  (('develop', 'anthrax'), 1),
#  (('anthrax', 'nerve'), 1),
#  (('nerve', 'gas'), 1),
#  (('gas', 'nuclear'), 1),
#  (('weapons', 'decade'), 1),
#  (('decade', 'regime'), 1),
#  (('regime', 'already'), 1),
#  (('already', 'used'), 1),
#  (('used', 'poison'), 1),
#  (('poison', 'gas'), 1),
#  (('gas', 'murder'), 1),
#  (('murder', 'thousands'), 1),
#  (('thousands', 'citizens'), 1),
#  (('citizens', 'leaving'), 1),
#  (('leaving', 'bodies'), 1),
#  (('bodies', 'mothers'), 1),
#  (('mothers', 'huddled'), 1),
#  (('huddled', 'dead'), 1),
#  (('dead', 'children'), 1),
#  (('children', 'regime'), 1),
#  (('regime', 'agreed'), 1),
#  (('agreed', 'international'), 1),
#  (('international', 'inspections'), 1),
#  (('inspections', 'kicked'), 1),
#  (('kicked', 'inspectors'), 1),
#  (('inspectors', 'regime'), 1),
#  (('regime', 'something'), 1),
#  (('something', 'hide'), 1),
#  (('hide', 'civilized'), 1),
#  (('world', 'states'), 1),
#  (('states', 'like'), 1),
#  (('like', 'terrorist'), 1),
#  (('terrorist', 'allies'), 1),
#  (('allies', 'constitute'), 1),
#  (('constitute', 'axis'), 1),
#  (('axis', 'evil'), 1),
#  (('evil', 'arming'), 1),
#  (('arming', 'threaten'), 1),
#  (('threaten', 'peace'), 1),
#  (('peace', 'world'), 1),
#  (('world', 'seeking'), 1),
#  (('seeking', 'weapons'), 1),
#  (('regimes', 'pose'), 1),
#  (('pose', 'grave'), 1),
#  (('grave', 'growing'), 1),
#  (('growing', 'danger'), 1),
#  (('danger', 'could'), 1),
#  (('could', 'provide'), 1),
#  (('provide', 'arms'), 1),
#  (('arms', 'terrorists'), 1),
#  (('terrorists', 'giving'), 1),
#  (('giving', 'means'), 1),
#  (('means', 'match'), 1),
#  (('match', 'hatred'), 1),
#  (('hatred', 'could'), 1),
#  (('could', 'attack'), 1),
#  (('attack', 'allies'), 1),
#  (('allies', 'attempt'), 1),
#  (('attempt', 'blackmail'), 1),
#  (('blackmail', 'united'), 1),
#  (('states', 'cases'), 1),
#  (('cases', 'price'), 1),
#  (('price', 'indifference'), 1),
#  (('indifference', 'would'), 1),
#  (('would', 'catastrophic'), 1),
#  (('catastrophic', 'work'), 1),
#  (('work', 'closely'), 1),
#  (('closely', 'coalition'), 1),
#  (('coalition', 'deny'), 1),
#  (('deny', 'terrorists'), 1),
#  (('terrorists', 'state'), 1),
#  (('state', 'sponsors'), 1),
#  (('sponsors', 'materials'), 1),
#  (('materials', 'technology'), 1),
#  (('technology', 'expertise'), 1),
#  (('expertise', 'make'), 1),
#  (('make', 'deliver'), 1),
#  (('deliver', 'weapons'), 1),
#  (('destruction', 'develop'), 1),
#  (('develop', 'deploy'), 1),
#  (('deploy', 'effective'), 1),
#  (('effective', 'missile'), 1),
#  (('missile', 'defenses'), 1),
#  (('defenses', 'protect'), 1),
#  (('protect', 'america'), 1),
#  (('allies', 'sudden'), 1),
#  (('sudden', 'attack'), 1),
#  (('attack', 'nations'), 1),
#  (('nations', 'know'), 1),
#  (('know', 'america'), 1),
#  (('america', 'necessary'), 1),
#  (('necessary', 'ensure'), 1),
#  (('ensure', 'nation'), 1),
#  (('nation', 'security'), 1),
#  (('security', 'deliberate'), 1),
#  (('deliberate', 'yet'), 1),
#  (('yet', 'time'), 1),
#  (('time', 'side'), 1),
#  (('side', 'wait'), 1),
#  (('wait', 'events'), 1),
#  (('events', 'dangers'), 1),
#  (('dangers', 'gather'), 1),
#  (('gather', 'stand'), 1),
#  (('stand', 'peril'), 1),
#  (('peril', 'draws'), 1),
#  (('draws', 'closer'), 1),
#  (('closer', 'closer'), 1),
#  (('closer', 'united'), 1),
#  (('states', 'america'), 1),
#  (('america', 'permit'), 1),
#  (('permit', 'world'), 1),
#  (('world', 'dangerous'), 1),
#  (('dangerous', 'regimes'), 1),
#  (('regimes', 'threaten'), 1),
#  (('threaten', 'us'), 1),
#  (('us', 'world'), 1),
#  (('world', 'destructive'), 1),
#  (('destructive', 'weapons'), 1),
#  (('weapons', 'war'), 1),
#  (('terror', 'well'), 1),
#  (('well', 'begun'), 1),
#  (('begun', 'begun'), 1),
#  (('begun', 'campaign'), 1),
#  (('campaign', 'may'), 1),
#  (('may', 'finished'), 1),
#  (('finished', 'watch'), 1),
#  (('watch', 'yet'), 1),
#  (('yet', 'must'), 1),
#  (('must', 'waged'), 1),
#  (('waged', 'watch'), 1),
#  (('watch', 'stop'), 1),
#  (('stop', 'short'), 1),
#  (('short', 'stop'), 1),
#  (('stop', 'leaving'), 1),
#  (('leaving', 'terror'), 1),
#  (('terror', 'camps'), 1),
#  (('camps', 'intact'), 1),
#  (('intact', 'terrorist'), 1),
#  (('terrorist', 'states'), 1),
#  (('states', 'unchecked'), 1),
#  (('unchecked', 'sense'), 1),
#  (('sense', 'security'), 1),
#  (('security', 'would'), 1),
#  (('would', 'false'), 1),
#  (('false', 'temporary'), 1),
#  (('temporary', 'history'), 1),
#  (('history', 'called'), 1),
#  (('called', 'america'), 1),
#  (('allies', 'action'), 1),
#  (('action', 'responsibility'), 1),
#  (('responsibility', 'privilege'), 1),
#  (('privilege', 'fight'), 1),
#  (('fight', 'freedom'), 1),
#  (('freedom', 'fight'), 1),
#  (('fight', 'first'), 1),
#  (('first', 'priority'), 1),
#  (('priority', 'must'), 1),
#  (('always', 'security'), 1),
#  (('security', 'nation'), 1),
#  (('nation', 'reflected'), 1),
#  (('reflected', 'budget'), 1),
#  (('budget', 'send'), 1),
#  (('send', 'congress'), 1),
#  (('congress', 'budget'), 1),
#  (('budget', 'supports'), 1),
#  (('supports', 'three'), 1),
#  (('three', 'great'), 1),
#  (('great', 'goals'), 1),
#  (('goals', 'america'), 1),
#  (('america', 'win'), 1),
#  (('homeland', 'revive'), 1),
#  (('revive', 'economy'), 1),
#  (('economy', 'september'), 1),
#  (('11th', 'brought'), 1),
#  (('brought', 'best'), 1),
#  (('best', 'america'), 1),
#  (('america', 'best'), 1),
#  (('best', 'congress'), 1),
#  (('join', 'american'), 1),
#  (('people', 'applauding'), 1),
#  (('applauding', 'unity'), 1),
#  (('unity', 'resolve'), 1),
#  (('resolve', 'americans'), 1),
#  (('americans', 'deserve'), 1),
#  (('deserve', 'spirit'), 1),
#  (('spirit', 'directed'), 1),
#  (('directed', 'toward'), 1),
#  (('toward', 'addressing'), 1),
#  (('addressing', 'problems'), 1),
#  (('problems', 'home'), 1),
#  (('home', 'proud'), 1),
#  (('proud', 'member'), 1),
#  (('member', 'party'), 1),
#  (('party', 'yet'), 1),
#  (('yet', 'act'), 1),
#  (('act', 'win'), 1),
#  (('protect', 'people'), 1),
#  (('people', 'create'), 1),
#  (('jobs', 'america'), 1),
#  (('act', 'first'), 1),
#  (('first', 'foremost'), 1),
#  (('foremost', 'republicans'), 1),
#  (('democrats', 'americans'), 1),
#  (('americans', 'costs'), 1),
#  (('costs', 'lot'), 1),
#  (('lot', 'fight'), 1),
#  (('fight', 'war'), 1),
#  (('war', 'spent'), 1),
#  (('spent', 'billion'), 1),
#  (('billion', 'dollars'), 1),
#  (('dollars', 'month'), 1),
#  (('month', '30'), 1),
#  (('30', 'million'), 1),
#  (('million', 'day'), 1),
#  (('day', 'must'), 1),
#  (('must', 'prepared'), 1),
#  (('prepared', 'future'), 1),
#  (('future', 'operations'), 1),
#  (('operations', 'afghanistan'), 1),
#  (('afghanistan', 'proved'), 1),
#  (('proved', 'expensive'), 1),
#  (('expensive', 'precision'), 1),
#  (('precision', 'weapons'), 1),
#  (('weapons', 'defeat'), 1),
#  (('defeat', 'enemy'), 1),
#  (('enemy', 'spare'), 1),
#  (('spare', 'innocent'), 1),
#  (('innocent', 'lives'), 1),
#  (('lives', 'need'), 1),
#  (('need', 'need'), 1),
#  (('need', 'replace'), 1),
#  (('replace', 'aging'), 1),
#  (('aging', 'aircraft'), 1),
#  (('aircraft', 'make'), 1),
#  (('make', 'military'), 1),
#  (('military', 'agile'), 1),
#  (('agile', 'put'), 1),
#  (('put', 'troops'), 1),
#  (('troops', 'anywhere'), 1),
#  (('anywhere', 'world'), 1),
#  (('world', 'quickly'), 1),
#  (('quickly', 'safely'), 1),
#  (('safely', 'men'), 1),
#  (('women', 'uniform'), 1),
#  (('uniform', 'deserve'), 1),
#  (('deserve', 'best'), 1),
#  (('best', 'weapons'), 1),
#  (('weapons', 'best'), 1),
#  (('best', 'equipment'), 1),
#  (('equipment', 'best'), 1),
#  (('best', 'training'), 1),
#  (('training', 'also'), 1),
#  (('also', 'deserve'), 1),
#  (('deserve', 'another'), 1),
#  (('another', 'pay'), 1),
#  (('pay', 'raise'), 1),
#  (('raise', 'budget'), 1),
#  (('budget', 'includes'), 1),
#  (('includes', 'largest'), 1),
#  (('largest', 'increase'), 1),
#  (('increase', 'defense'), 1),
#  (('defense', 'spending'), 1),
#  (('spending', 'two'), 1),
#  (('two', 'decades'), 1),
#  (('decades', 'price'), 1),
#  (('price', 'freedom'), 1),
#  (('freedom', 'security'), 1),
#  (('security', 'high'), 1),
#  (('high', 'never'), 1),
#  (('never', 'high'), 1),
#  (('high', 'whatever'), 1),
#  (('whatever', 'costs'), 1),
#  (('costs', 'defend'), 1),
#  (('defend', 'country'), 1),
#  (('country', 'pay'), 1),
#  (('pay', 'next'), 1),
#  (('next', 'priority'), 1),
#  (('budget', 'everything'), 1),
#  (('everything', 'possible'), 1),
#  (('possible', 'protect'), 1),
#  (('protect', 'citizens'), 1),
#  (('citizens', 'strengthen'), 1),
#  (('strengthen', 'nation'), 1),
#  (('nation', 'ongoing'), 1),
#  (('ongoing', 'threat'), 1),
#  (('threat', 'another'), 1),
#  (('another', 'attack'), 1),
#  (('attack', 'time'), 1),
#  (('time', 'distance'), 1),
#  (('distance', 'events'), 1),
#  (('events', 'september'), 1),
#  (('11th', 'make'), 1),
#  (('make', 'us'), 1),
#  (('us', 'safer'), 1),
#  (('safer', 'unless'), 1),
#  (('unless', 'act'), 1),
#  (('act', 'lessons'), 1),
#  (('lessons', 'america'), 1),
#  (('america', 'longer'), 1),
#  (('longer', 'protected'), 1),
#  (('protected', 'vast'), 1),
#  (('vast', 'oceans'), 1),
#  (('oceans', 'protected'), 1),
#  (('protected', 'attack'), 1),
#  (('attack', 'vigorous'), 1),
#  (('vigorous', 'action'), 1),
#  (('action', 'abroad'), 1),
#  (('abroad', 'increased'), 1),
#  (('increased', 'vigilance'), 1),
#  (('vigilance', 'home'), 1),
#  (('home', 'budget'), 1),
#  (('budget', 'nearly'), 1),
#  (('nearly', 'doubles'), 1),
#  (('doubles', 'funding'), 1),
#  (('funding', 'sustained'), 1),
#  (('sustained', 'strategy'), 1),
#  (('strategy', 'homeland'), 1),
#  (('security', 'focused'), 1),
#  (('focused', 'four'), 1),
#  (('four', 'key'), 1),
#  (('key', 'areas'), 1),
#  (('areas', 'bioterrorism'), 1),
#  (('bioterrorism', 'emergency'), 1),
#  (('emergency', 'response'), 1),
#  (('response', 'airport'), 1),
#  (('airport', 'border'), 1),
#  (('border', 'security'), 1),
#  (('security', 'improved'), 1),
#  (('improved', 'intelligence'), 1),
#  (('intelligence', 'develop'), 1),
#  (('develop', 'vaccines'), 1),
#  (('vaccines', 'fight'), 1),
#  (('fight', 'anthrax'), 1),
#  (('anthrax', 'deadly'), 1),
#  (('deadly', 'diseases'), 1),
#  (('diseases', 'increase'), 1),
#  (('increase', 'funding'), 1),
#  (('funding', 'help'), 1),
#  (('help', 'states'), 1),
#  (('states', 'communities'), 1),
#  (('communities', 'train'), 1),
#  (('train', 'equip'), 1),
#  (('equip', 'heroic'), 1),
#  (('heroic', 'police'), 1),
#  (('police', 'firefighters'), 1),
#  (('firefighters', 'improve'), 1),
#  (('improve', 'intelligence'), 1),
#  (('intelligence', 'collection'), 1),
#  (('collection', 'sharing'), 1),
#  (('sharing', 'expand'), 1),
#  (('expand', 'patrols'), 1),
#  (('patrols', 'borders'), 1),
#  (('borders', 'strengthen'), 1),
#  (('strengthen', 'security'), 1),
#  (('security', 'air'), 1),
#  (('air', 'travel'), 1),
#  (('travel', 'use'), 1),
#  (('use', 'technology'), 1),
#  (('technology', 'track'), 1),
#  (('track', 'arrivals'), 1),
#  (('arrivals', 'departures'), 1),
#  (('departures', 'visitors'), 1),
#  (('visitors', 'united'), 1),
#  (('states', 'homeland'), 1),
#  (('security', 'make'), 1),
#  (('make', 'america'), 1),
#  (('america', 'stronger'), 1),
#  (('stronger', 'many'), 1),
#  (('many', 'ways'), 1),
#  (('ways', 'better'), 1),
#  (('better', 'knowledge'), 1),
#  (('knowledge', 'gained'), 1),
#  (('gained', 'bioterrorism'), 1),
#  (('bioterrorism', 'research'), 1),
#  (('research', 'improve'), 1),
#  (('improve', 'public'), 1),
#  (('public', 'health'), 1),
#  (('health', 'stronger'), 1),
#  (('stronger', 'police'), 1),
#  (('departments', 'mean'), 1),
#  (('mean', 'safer'), 1),
#  (('safer', 'neighborhoods'), 1),
#  (('neighborhoods', 'stricter'), 1),
#  (('stricter', 'border'), 1),
#  (('border', 'enforcement'), 1),
#  (('enforcement', 'help'), 1),
#  (('help', 'combat'), 1),
#  (('combat', 'illegal'), 1),
#  (('illegal', 'drugs'), 1),
#  (('drugs', 'government'), 1),
#  (('government', 'works'), 1),
#  (('works', 'better'), 1),
#  (('better', 'secure'), 1),
#  (('secure', 'homeland'), 1),
#  (('homeland', 'america'), 1),
#  (('america', 'continue'), 1),
#  (('continue', 'depend'), 1),
#  (('depend', 'eyes'), 1),
#  ...]

# %% [markdown]
# <h3 style="color:blue;">Exercises for Part VI</h3>
#
# <p style="color:blue;">21b. Create ngrams from sotu2. Try bigrams, trigrams, and even ngrams of length 4. Then identify the most common of these ngrams. Are these results useful to understanding this particular text?</p>

# %% [markdown]
# ## VII. Other NLTK functions

# %%
text1 = nltk.Text(tokens) #to use many of nltk's functions we need to convert our tokens list into a nltk.Text object
    #remember, the tokens variable stores our first set of tokens derived from Washington's 1794 address
    ## for concordances, it makes sense to work with unmodified tokens (in original case with all words and punctuation
    ## still included)
text1.concordance("government")
# Out:
# Displaying 4 of 4 matches:
# and are part of Afghanistan s new Government And we welcome the new Minister o
# soldiers working with the Bosnian Government seized terrorists who were plotti
#  help combat illegal drugs And as government works to better secure our homela
# e goal is to reduce dependency on government and offer every American the dign

# %%
text1.collocations()
# Out:
# United States; Good jobs; mass destruction; Freedom Corps; USA
# Freedom; tax relief; create jobs; must act; New York; Social Security;
# fire departments; economic security; training camps; ask Congress;
# American people; homeland security; civilized world; last time; needs
# citizens; nuclear weapons

# %%
text1.count("terror")
# Out:
# 13

# %%
text1.dispersion_plot(["freedom", "God", "liberty", "war"])

# %%
text1.similar("freedom")
# Out:
# shock terror weapons september soldiers peace firefighters charities
# service americorps learning suicide

# %% [markdown]
# <h3 style="color:blue;">Exercises for Part VII</h3>
#
# <p style="color:blue;">Read the tokens from sotu2 into nltk.Text. Then try applying some of the nltk functions introduced above.</p>
